# %% [markdown]
# ## Seasonality Understanding

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

df_zc = pd.read_csv("../data/labels_hierarchy.csv")
df_seasonality = pd.read_csv("../data/labels_hierarchy_seasonality.csv")

# make a set of the lnf codes in both df (the value in the colum is a list of ints)
set_zc = set([int(x) for x in df_zc["lnf_codes"].apply(eval).sum()])
set_seasonality = set([int(x) for x in df_seasonality["lnf_codes"].apply(eval).sum()])

print(f"Number of unique lnf codes in ZC: {len(set_zc)}")
print(f"Number of unique lnf codes in Seasonality: {len(set_seasonality)}")

# get the intersection of the two sets
intersection = set_zc.intersection(set_seasonality)

print(f"Number of common lnf codes in ZC and Seasonality: {len(intersection)}")
# Out:
# Number of unique lnf codes in ZC: 80
# Number of unique lnf codes in Seasonality: 138
# Number of common lnf codes in ZC and Seasonality: 79

# %%
def get_label_slug_by_lnf_code(df, lnf_code):
    df['lnf_codes_list'] = df["lnf_codes"].apply(eval)
    df["lnf_codes_list"] = df["lnf_codes_list"].apply(lambda x: [int(i) for i in x])
    return df[df["lnf_codes_list"].apply(lambda x: int(lnf_code) in x)]['label_slug'].values[0]

df_lnf_lookup = pd.read_csv("../archive/input/LNF_Katalog_Nutzungsart.csv")

# %% [markdown]
# **Which LNF Codes are new in Seasonality?**

# %%
# get the ones new in seasonality
new_in_seasonality = set_seasonality - set_zc
print(f"Number of new lnf codes in Seasonality: {len(new_in_seasonality)}")
# Out:
# Number of new lnf codes in Seasonality: 59

# %%
df_new_in_seasonality = pd.DataFrame(columns=["lnf_code", "label_slug", "nutzung_de"])
rows = []

for lnf_code in new_in_seasonality:
    label_slug = get_label_slug_by_lnf_code(df_seasonality, lnf_code)
    nutzung_de = df_lnf_lookup[df_lnf_lookup["LNF_Code"] == lnf_code]["Nutzung_DE"].values[0]
    rows.append({"lnf_code": lnf_code, "label_slug": label_slug, "nutzung_de": nutzung_de})

df_new_in_seasonality = pd.concat([df_new_in_seasonality, pd.DataFrame(rows)], ignore_index=True)
df_new_in_seasonality
# Out:
#    lnf_code                                        label_slug  \
# 0       520                     Vegetation_AnnualCrop_DryRice
# 1       650                 Vegetation_Permaculture_Grassland
# 2       529                     Vegetation_AnnualCrop_WetRice
# 3       660                 Vegetation_Permaculture_Grassland
# 4       921                  Vegetation_Permaculture_Orchards
# 5       922                  Vegetation_Permaculture_Orchards
# 6       923                 Vegetation_Permaculture_Chestnuts
# 7       540                   Vegetation_AnnualCrop_Chickpeas
# 8       797                 Vegetation_Permaculture_Grassland
# 9       798                 Vegetation_Permaculture_Grassland
# 10      924                  Vegetation_Permaculture_Orchards
# 11      927                  Vegetation_Permaculture_Orchards
# 12      933                 Vegetation_Permaculture_Grassland
# 13      935                 Vegetation_Permaculture_Grassland
# 14      552        Vegetation_AnnualCrop_SpecialCultureAnnual
# 15      553        Vegetation_AnnualCrop_SpecialCultureAnnual
# 16      554        Vegetation_AnnualCrop_SpecialCultureAnnual
# 17      559                 Vegetation_Permaculture_Grassland
# 18      951        Vegetation_AnnualCrop_SpecialCultureAnnual
# 19      693                 Vegetation_Permaculture_Grassland
# 20      566                       Vegetation_AnnualCrop_Poppy
# 21      567                   Vegetation_AnnualCrop_Safflower
# 22      568                     Vegetation_AnnualCrop_Lentils
# 23      694                 Vegetation_Permaculture_Grassland
# 24      570                     Vegetation_AnnualCrop_CropMix
# 25      697                 Vegetation_Permaculture_Grassland
# 26      698                 Vegetation_Permaculture_Grassland
# 27      950                 Vegetation_Permaculture_Grassland
# 28      574                      Vegetation_AnnualCrop_Quinoa
# 29      575                        Vegetation_AnnualCrop_Hemp
# 30      576                        Vegetation_AnnualCrop_Hemp
# 31      577                        Vegetation_AnnualCrop_Hemp
# 32      578                      Vegetation_AnnualCrop_Millet
# 33      579                      Vegetation_AnnualCrop_Millet
# 34      580                     Vegetation_AnnualCrop_Sorghum
# 35      581                     Vegetation_AnnualCrop_Sorghum
# 36      706  Vegetation_PerennialCrop_SpecialCulturePerennial
# 37      707  Vegetation_PerennialCrop_SpecialCulturePerennial
# 38      709        Vegetation_AnnualCrop_SpecialCultureAnnual
# 39      710  Vegetation_PerennialCrop_SpecialCulturePerennial
# 40      711        Vegetation_AnnualCrop_SpecialCultureAnnual
# 41      714       Vegetation_Permaculture_SpecialCulturePerma
# 42      715       Vegetation_Permaculture_SpecialCulturePerma
# 43      590              Vegetation_AnnualCrop_SummerRapeseed
# 44      718                  Vegetation_Permaculture_Orchards
# 45      719                  Vegetation_Permaculture_Orchards
# 46      721       Vegetation_Permaculture_SpecialCulturePerma
# 47      723       Vegetation_Permaculture_SpecialCulturePerma
# 48      724       Vegetation_Permaculture_SpecialCulturePerma
# 49      725       Vegetation_Permaculture_SpecialCulturePerma
# 50      730                  Vegetation_Permaculture_Orchards
# 51      731                  Vegetation_Permaculture_Orchards
# 52      750                 Vegetation_Permaculture_Grassland
# 53      623                 Vegetation_Permaculture_Grassland
# 54      760                 Vegetation_Permaculture_Grassland
# 55      632                 Vegetation_Permaculture_Grassland
# 56      635                 Vegetation_Permaculture_Grassland
# 57      509                        Vegetation_AnnualCrop_Rice
# 58      510                   Vegetation_AnnualCrop_HardWheat
#
#                                                                                                                nutzung_de
# 0                                                                                                             Trockenreis
# 1                                                                       Übrige Dauerwiesen, beitragsberechtigt aggregiert
# 2                                                                                                                Nassreis
# 3                                                                       Übrige Dauerweiden, beitragsberechtigt aggregiert
# 4                                                                           Hochstamm-Feldobstbäume (Punkte oder Flächen)
# 5                                                                                         Nussbäume (Punkte oder Flächen)
# 6                                                                                                      Edelkastanienbäume
# 7                                                                                                            Kichererbsen
# 8                                                                    Übrige Flächen mit Dauerkulturen, beitragsberechtigt
# 9                                                              Übrige Flächen mit Dauerkulturen, nicht beitragsberechtigt
# 10                                             Einheimische standortgerechte Einzelbäume und Alleen (Punkte oder Flächen)
# 11                                                           Andere Bäume (regionsspezifische Biodiversitätsförderfläche)
# 12                                                                                                    Gemeinschaftsweiden
# 13                                                                        Heuwiesen mit Zufütterung während der Sömmerung
# 14                                                                       Einjährige nachwachsende Rohstoffe (Kenaf, usw.)
# 15                                                                               Einjährige Gewürz- und Medizinalpflanzen
# 16                                                      Einjährige gärtnerische Freilandkulturen (Blumen, Rollrasen usw.)
# 17                                                                                                  Saum auf Ackerflächen
# 18                                                                                              Getreide in weiter Reihen
# 19                                                                Regionsspezifische Biodiversitätsförderflächen (Weiden)
# 20                                                                                                                   Mohn
# 21                                                                                                                 Saflor
# 22                                                                                                                 Linsen
# 23                                                Regionsspezifische Biodiversitätsförderfläche (Grünflächen ohne Weiden)
# 24  Mischungen von Linsen mit Getreide oder Leindotter, mindestens 30 % Anteil Linsen bei der Ernte (zur Körnergewinnung)
# 25                                                                Übrige Grünfläche (Dauergrünfläche), beitragsberechtigt
# 26                                                         Übrige Grünfläche (Dauergrünflächen), nicht beitragsberechtigt
# 27                                                                                                     Ackerschonstreifen
# 28                                                                                                                 Quinoa
# 29                                                                                             Hanf zur Nutzung der Samen
# 30                                                                                                  Hanf zur Fasernutzung
# 31                                                                                                           Anderer Hanf
# 32                                                                                              Hirse zur Körnergewinnung
# 33                                                                                        Hirse zur Nutzung ganze Pflanze
# 34                                                                                            Sorghum zur Körnergewinnung
# 35                                                                                      Sorghum zur Nutzung ganze Pflanze
# 36                                                                              Mehrjährige Gewürz- und Medizinalpflanzen
# 37                                                                Mehrjährige nachwachsende Rohstoffe (Chinaschilf, usw.)
# 38                                                                                                              Rhabarber
# 39                                                                                                                Spargel
# 40                                                                                                       Pilze (Freiland)
# 41                                                                             Ziersträucher, Ziergehölze und Zierstauden
# 42                                                                              Übrige Baumschulen (Rosen, Früchte, usw.)
# 43                                                                                 Sommerraps als nachwachsender Rohstoff
# 44                                                                                                         Trüffelanlagen
# 45                                                                           Maulbeerbaumanlagen (Fütterung Seidenraupen)
# 46                                                       Mehrjährige gärtnerische Freilandkulturen (nicht im Gewächshaus)
# 47                                                                                        Baumschulen von Obst und Beeren
# 48                                                                          Übrige Baumschulen (Rosen, Zierstauden, usw.)
# 49                                                                                                            Permakultur
# 50                                                                                                 Obstanlagen aggregiert
# 51                                                                              Andere Obstanlagen (Kiwis, Holunder usw.)
# 52                                                                   Übrige Dauerkulturen, beitragsberechtigt, aggregiert
# 53                                                       Heuwiesen im Sömmerungsgebiet, Typ wenig intensiv genutzte Wiese
# 54                                                                    Dauerkulturen, nicht beitragsberechtigt, aggregiert
# 55                                                                   Futtergräser für die Samenproduktion (Vertragsanbau)
# 56                                                                                               Uferwiesen (ohne Weiden)
# 57                                                                                                                   Reis
# 58                                                                                                             Hartweizen

# %% [markdown]
# **Which LNF Codes are missing in Seasonality?**

# %%
# the ones missing in seasonality
missing_in_seasonality = set_zc - set_seasonality
print(f"Number of lnf codes missing in Seasonality: {len(missing_in_seasonality)}")
# Out:
# Number of lnf codes missing in Seasonality: 1

# %%
df_missing_in_seasonality = pd.DataFrame(columns=["lnf_code", "label_slug_zc", "nutzung_de"])
rows = []

for lnf_code in missing_in_seasonality:
    label_slug = get_label_slug_by_lnf_code(df_zc, lnf_code)
    nutzung_de = df_lnf_lookup[df_lnf_lookup["LNF_Code"] == lnf_code]["Nutzung_DE"].values[0]
    rows.append({"lnf_code": lnf_code, "label_slug_zc": label_slug, "nutzung_de": nutzung_de})

df_missing_in_seasonality = pd.concat([df_missing_in_seasonality, pd.DataFrame(rows)], ignore_index=True)

df_missing_in_seasonality
# Out:
#   lnf_code                    label_slug_zc nutzung_de
# 0      901  Vegetation_Forest_Forest_Forest       Wald
