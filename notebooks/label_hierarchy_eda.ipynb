# %% [markdown]
# ## Seasonality Understanding

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

df_zc = pd.read_csv("../data/labels_hierarchy.csv")
df_seasonality = pd.read_csv("../data/labels_hierarchy_seasonality.csv")
df_seasonality_reduced = pd.read_csv("../data/labels_hierarchy_seasonality_reduced.csv")

# make a set of the lnf codes in both df (the value in the colum is a list of ints)
set_zc = set([int(x) for x in df_zc["lnf_codes"].apply(eval).sum()])
set_seasonality = set([int(x) for x in df_seasonality["lnf_codes"].apply(eval).sum()])
set_seasonality_reduced = set([int(x) for x in df_seasonality_reduced["lnf_codes"].apply(eval).sum()])

print(f"Number of unique lnf codes in ZC: {len(set_zc)}")
print(f"Number of unique lnf codes in Seasonality: {len(set_seasonality)}")
print(f"Number of unique lnf codes in Seasonality reduced: {len(set_seasonality_reduced)}")

# get the intersection of the two sets
intersection = set_zc.intersection(set_seasonality)
intersection_reduced = set_zc.intersection(set_seasonality_reduced)

print(f"Number of common lnf codes in ZC and Seasonality: {len(intersection)}")
print(f"Number of common lnf codes in ZC and Seasonality reduced: {len(intersection_reduced)}")
# Out:
# Number of unique lnf codes in ZC: 80
# Number of unique lnf codes in Seasonality: 133
# Number of unique lnf codes in Seasonality reduced: 104
# Number of common lnf codes in ZC and Seasonality: 79
# Number of common lnf codes in ZC and Seasonality reduced: 64

# %%
def get_label_slug_by_lnf_code(df, lnf_code):
    df['lnf_codes_list'] = df["lnf_codes"].apply(eval)
    df["lnf_codes_list"] = df["lnf_codes_list"].apply(lambda x: [int(i) for i in x])
    return df[df["lnf_codes_list"].apply(lambda x: int(lnf_code) in x)]['label_slug'].values[0]

df_lnf_lookup = pd.read_csv("../archive/input/LNF_Katalog_Nutzungsart.csv")

# %% [markdown]
# **Which LNF Codes are new in Seasonality?**

# %%
# get the ones new in seasonality
new_in_seasonality = set_seasonality - set_zc
print(f"Number of new lnf codes in Seasonality: {len(new_in_seasonality)}")
# Out:
# Number of new lnf codes in Seasonality: 54

# %%
df_new_in_seasonality = pd.DataFrame(columns=["lnf_code", "label_slug", "nutzung_de"])
rows = []

for lnf_code in new_in_seasonality:
    label_slug = get_label_slug_by_lnf_code(df_seasonality, lnf_code)
    nutzung_de = df_lnf_lookup[df_lnf_lookup["LNF_Code"] == lnf_code]["Nutzung_DE"].values[0]
    rows.append({"lnf_code": lnf_code, "label_slug": label_slug, "nutzung_de": nutzung_de})

df_new_in_seasonality = pd.concat([df_new_in_seasonality, pd.DataFrame(rows)], ignore_index=True)
df_new_in_seasonality
# Out:
#    lnf_code                                        label_slug  \
# 0       650                 Vegetation_Permaculture_Grassland
# 1       660                 Vegetation_Permaculture_Grassland
# 2       921                  Vegetation_Permaculture_Orchards
# 3       922                  Vegetation_Permaculture_Orchards
# 4       923                 Vegetation_Permaculture_Chestnuts
# 5       924                  Vegetation_Permaculture_Orchards
# 6       797                 Vegetation_Permaculture_Grassland
# 7       798                 Vegetation_Permaculture_Grassland
# 8       927                  Vegetation_Permaculture_Orchards
# 9       933                 Vegetation_Permaculture_Grassland
# 10      935                 Vegetation_Permaculture_Grassland
# 11      552        Vegetation_AnnualCrop_SpecialCultureAnnual
# 12      553        Vegetation_AnnualCrop_SpecialCultureAnnual
# 13      554        Vegetation_AnnualCrop_SpecialCultureAnnual
# 14      559                 Vegetation_Permaculture_Grassland
# 15      951        Vegetation_AnnualCrop_SpecialCultureAnnual
# 16      693                 Vegetation_Permaculture_Grassland
# 17      566                       Vegetation_AnnualCrop_Poppy
# 18      567                   Vegetation_AnnualCrop_Safflower
# 19      568                     Vegetation_AnnualCrop_Lentils
# 20      694                 Vegetation_Permaculture_Grassland
# 21      570                     Vegetation_AnnualCrop_CropMix
# 22      697                 Vegetation_Permaculture_Grassland
# 23      698                 Vegetation_Permaculture_Grassland
# 24      950                 Vegetation_Permaculture_Grassland
# 25      574                      Vegetation_AnnualCrop_Quinoa
# 26      575                        Vegetation_AnnualCrop_Hemp
# 27      576                        Vegetation_AnnualCrop_Hemp
# 28      577                        Vegetation_AnnualCrop_Hemp
# 29      578                      Vegetation_AnnualCrop_Millet
# 30      579                      Vegetation_AnnualCrop_Millet
# 31      580                     Vegetation_AnnualCrop_Sorghum
# 32      581                     Vegetation_AnnualCrop_Sorghum
# 33      706  Vegetation_PerennialCrop_SpecialCulturePerennial
# 34      707  Vegetation_PerennialCrop_SpecialCulturePerennial
# 35      709        Vegetation_AnnualCrop_SpecialCultureAnnual
# 36      710  Vegetation_PerennialCrop_SpecialCulturePerennial
# 37      711        Vegetation_AnnualCrop_SpecialCultureAnnual
# 38      714       Vegetation_Permaculture_SpecialCulturePerma
# 39      715       Vegetation_Permaculture_SpecialCulturePerma
# 40      590              Vegetation_AnnualCrop_SummerRapeseed
# 41      718                  Vegetation_Permaculture_Orchards
# 42      719                  Vegetation_Permaculture_Orchards
# 43      721       Vegetation_Permaculture_SpecialCulturePerma
# 44      723       Vegetation_Permaculture_SpecialCulturePerma
# 45      724       Vegetation_Permaculture_SpecialCulturePerma
# 46      725       Vegetation_Permaculture_SpecialCulturePerma
# 47      730                  Vegetation_Permaculture_Orchards
# 48      731                  Vegetation_Permaculture_Orchards
# 49      750                 Vegetation_Permaculture_Grassland
# 50      623                 Vegetation_Permaculture_Grassland
# 51      760                 Vegetation_Permaculture_Grassland
# 52      632                 Vegetation_Permaculture_Grassland
# 53      635                 Vegetation_Permaculture_Grassland
#
#                                                                                                                nutzung_de
# 0                                                                       Übrige Dauerwiesen, beitragsberechtigt aggregiert
# 1                                                                       Übrige Dauerweiden, beitragsberechtigt aggregiert
# 2                                                                           Hochstamm-Feldobstbäume (Punkte oder Flächen)
# 3                                                                                         Nussbäume (Punkte oder Flächen)
# 4                                                                                                      Edelkastanienbäume
# 5                                              Einheimische standortgerechte Einzelbäume und Alleen (Punkte oder Flächen)
# 6                                                                    Übrige Flächen mit Dauerkulturen, beitragsberechtigt
# 7                                                              Übrige Flächen mit Dauerkulturen, nicht beitragsberechtigt
# 8                                                            Andere Bäume (regionsspezifische Biodiversitätsförderfläche)
# 9                                                                                                     Gemeinschaftsweiden
# 10                                                                        Heuwiesen mit Zufütterung während der Sömmerung
# 11                                                                       Einjährige nachwachsende Rohstoffe (Kenaf, usw.)
# 12                                                                               Einjährige Gewürz- und Medizinalpflanzen
# 13                                                      Einjährige gärtnerische Freilandkulturen (Blumen, Rollrasen usw.)
# 14                                                                                                  Saum auf Ackerflächen
# 15                                                                                              Getreide in weiter Reihen
# 16                                                                Regionsspezifische Biodiversitätsförderflächen (Weiden)
# 17                                                                                                                   Mohn
# 18                                                                                                                 Saflor
# 19                                                                                                                 Linsen
# 20                                                Regionsspezifische Biodiversitätsförderfläche (Grünflächen ohne Weiden)
# 21  Mischungen von Linsen mit Getreide oder Leindotter, mindestens 30 % Anteil Linsen bei der Ernte (zur Körnergewinnung)
# 22                                                                Übrige Grünfläche (Dauergrünfläche), beitragsberechtigt
# 23                                                         Übrige Grünfläche (Dauergrünflächen), nicht beitragsberechtigt
# 24                                                                                                     Ackerschonstreifen
# 25                                                                                                                 Quinoa
# 26                                                                                             Hanf zur Nutzung der Samen
# 27                                                                                                  Hanf zur Fasernutzung
# 28                                                                                                           Anderer Hanf
# 29                                                                                              Hirse zur Körnergewinnung
# 30                                                                                        Hirse zur Nutzung ganze Pflanze
# 31                                                                                            Sorghum zur Körnergewinnung
# 32                                                                                      Sorghum zur Nutzung ganze Pflanze
# 33                                                                              Mehrjährige Gewürz- und Medizinalpflanzen
# 34                                                                Mehrjährige nachwachsende Rohstoffe (Chinaschilf, usw.)
# 35                                                                                                              Rhabarber
# 36                                                                                                                Spargel
# 37                                                                                                       Pilze (Freiland)
# 38                                                                             Ziersträucher, Ziergehölze und Zierstauden
# 39                                                                              Übrige Baumschulen (Rosen, Früchte, usw.)
# 40                                                                                 Sommerraps als nachwachsender Rohstoff
# 41                                                                                                         Trüffelanlagen
# 42                                                                           Maulbeerbaumanlagen (Fütterung Seidenraupen)
# 43                                                       Mehrjährige gärtnerische Freilandkulturen (nicht im Gewächshaus)
# 44                                                                                        Baumschulen von Obst und Beeren
# 45                                                                          Übrige Baumschulen (Rosen, Zierstauden, usw.)
# 46                                                                                                            Permakultur
# 47                                                                                                 Obstanlagen aggregiert
# 48                                                                              Andere Obstanlagen (Kiwis, Holunder usw.)
# 49                                                                   Übrige Dauerkulturen, beitragsberechtigt, aggregiert
# 50                                                       Heuwiesen im Sömmerungsgebiet, Typ wenig intensiv genutzte Wiese
# 51                                                                    Dauerkulturen, nicht beitragsberechtigt, aggregiert
# 52                                                                   Futtergräser für die Samenproduktion (Vertragsanbau)
# 53                                                                                               Uferwiesen (ohne Weiden)

# %% [markdown]
# **Which LNF Codes are missing in Seasonality?**

# %%
# the ones missing in seasonality
missing_in_seasonality = set_zc - set_seasonality
print(f"Number of lnf codes missing in Seasonality: {len(missing_in_seasonality)}")
# Out:
# Number of lnf codes missing in Seasonality: 1

# %%
df_missing_in_seasonality = pd.DataFrame(columns=["lnf_code", "label_slug_zc", "nutzung_de"])
rows = []

for lnf_code in missing_in_seasonality:
    label_slug = get_label_slug_by_lnf_code(df_zc, lnf_code)
    nutzung_de = df_lnf_lookup[df_lnf_lookup["LNF_Code"] == lnf_code]["Nutzung_DE"].values[0]
    rows.append({"lnf_code": lnf_code, "label_slug_zc": label_slug, "nutzung_de": nutzung_de})

df_missing_in_seasonality = pd.concat([df_missing_in_seasonality, pd.DataFrame(rows)], ignore_index=True)

df_missing_in_seasonality
# Out:
#   lnf_code                    label_slug_zc nutzung_de
# 0      901  Vegetation_Forest_Forest_Forest       Wald

# %% [markdown]
# # Cross Check with Original ZueriCrop labels.csv

# %%
import pandas as pd
df_zc_original = pd.read_csv("../archive/zueri-crop/labels.csv")

# drop whre 4th_tier_ENG is NaN
df_zc_original = df_zc_original.dropna(subset=["4th_tier_ENG"])

# unique values in 1st_tier
df_zc_original["1st_tier"].unique()

# Drop where 1st_tier is not Vegetation
df_zc_original = df_zc_original[df_zc_original["1st_tier"] == "Vegetation"]

df_zc_original

# Set of LNF_code
set_zc_original = set(df_zc_original["LNF_code"].values)

# count of unique LNF_code
print(f"Number of unique lnf codes in ZC original: {len(set_zc_original)}")
# Out:
# Number of unique lnf codes in ZC original: 80

# %% [markdown]
# Our adaption of the labels.csv is correct, 80 LNF Codes are considered in the original ZueriCrop dataset.
